# %%
import networkx as nx
import pandas as pd
import numpy as np
import eegraph
import stellargraph as sg
from spektral.data import Graph
import os
import pickle
from spektral.data import Dataset, DisjointLoader
import spektral 
import tensorflow as tf
from tensorflow.keras.optimizers import Adam


from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from spektral.layers import GCNConv, GlobalSumPool
from spektral.transforms import GCNFilter
from spektral.data import BatchLoader
from spektral.transforms.normalize_adj import NormalizeAdj
from spektral.layers.pooling import TopKPool
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import categorical_accuracy

from spektral.models.gcn import GCN

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## Variables a usar

# %%
path = '../Scripts/data/data_vigilia'              #<--------------- PATH TO FOLDER CONTAINING EEGs
window_size_class_0 = 1                                 #<--------------- CLASS 0 WINDOW SIZE
window_size_class_1 = 1                               #<--------------- CLASS 1 WINDOW SIZE
connectivity_number_total = 1                                
exclude = [] 
#CONNECTIVITY MEASURES USED
connectivity= "squared_coherence"
bands = ['theta', 'alpha', 'beta']

# %%
class MyDataset(Dataset):
    """
    A dataset of five random graphs.
    """
    def __init__(self, nodes, feats, **kwargs):
        self.graphs = nodes
        self.labels = feats

        super().__init__(**kwargs)


    def read(self):
        output=[]
        for i in range(len(self.graphs)):
            for j in range(len(self.graphs[i][0])):
                # por cada grupo de grafos creados accedemos a cada posicion del diccionario y le añadimos el label correspondiente
                output.append(
                    Graph(a=nx.adjacency_matrix(self.graphs[i][0][j]), y=labels[i][j])
                )

        return output

# %% [markdown]
# ## funcion modelar Grafo

# %%
def modelate_with_different_connectivity(window_size,entry, G, connectivity_number_total, connectivity, bands):
    total_graphs, total_labels = [], []
    #recorremos el numero de conectividades elegidas
    for i in range(connectivity_number_total):
        #creamos nuestro grafo modelado y guardamos nuestra matriz de adyacencia(no nos hace falta pero son datos que podrían venir bien en un futuro)
        graphs, c_m = G.modelate(window_size = window_size, connectivity = connectivity, bands = bands) #<--------------- THRESHOLD , threshold = 0.2          
      
        for i in range(len(graphs)):
            total_labels.append(str(entry))
        total_graphs.append(graphs) 
      
    return  total_graphs, total_labels

# %% [markdown]
# ## Abrir directorios e importar datos

# %%
def open_data_directories(path, window_size_class_0, window_size_class_1, exclude, connectivity_number_total,connectivity,bands):
    array_grafos= []
    array_labels=[]
    class_files = os.listdir(path)
    #recorremos todas las carpetas y ficheros del path dado
    for entry in class_files:
        eeg_files = os.listdir(path + '/' + entry)
        for eeg in eeg_files:
            eeg_path = (path + '/' + entry + '/' + eeg)
            print(eeg_path, entry)#imprimimos el path del archivo completo
            G = eegraph.Graph() #creamos un objeto de tipo eegraph
            G.load_data(path= eeg_path, exclude = exclude) # llamamos al objeto y cargamos el archivo seleccionado
            
            if(entry == '1'):
                window_size = window_size_class_1
            elif (entry == '0'):
                window_size = window_size_class_0
            #llamamos recursivamente a la función para modelar nuestro grafo con las medidas deseadas
            final_graphs, final_labels =  modelate_with_different_connectivity(window_size ,entry, G, connectivity_number_total,connectivity,bands)
            array_labels.append(final_labels)
            array_grafos.append(final_graphs)
           # labels = labels + final_labels
    return array_grafos,array_labels

# %% [markdown]
# ## llamada a las funciones y guardado de datos

# %%
#configs
learning_rate = 1e-2  # Learning rate
epochs = 400  # Number of training epochs
es_patience = 10  # Patience for early stopping
batch_size = 32  # Batch size

# %%
graphs,labels = open_data_directories(path, window_size_class_0, window_size_class_1, exclude, connectivity_number_total,connectivity,bands)
# Out:
# ../Scripts/data/data_vigilia/0/1_vigilia con 1.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 10.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 11.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 12.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 13.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 14.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 14.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 15.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 15.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 16.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 16.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 2.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 3.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 4.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 4.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 5.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 5.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 6.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 7.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 7.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia con 8.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 8.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia con 9.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia con 9.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 3.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2047.0)]
#
# Threshold: 0.65
# Number of graphs created: 12
# ../Scripts/data/data_vigilia/0/1_vigilia sin 1.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 8.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4607.0)]
#
# Threshold: 0.65
# Number of graphs created: 27
# ../Scripts/data/data_vigilia/0/1_vigilia sin 10.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 8.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4607.0)]
#
# Threshold: 0.65
# Number of graphs created: 27
# ../Scripts/data/data_vigilia/0/1_vigilia sin 2.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 7.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4095.0)]
#
# Threshold: 0.65
# Number of graphs created: 24
# ../Scripts/data/data_vigilia/0/1_vigilia sin 3.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 7.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4095.0)]
#
# Threshold: 0.65
# Number of graphs created: 24
# ../Scripts/data/data_vigilia/0/1_vigilia sin 4.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 4.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 8.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4607.0)]
#
# Threshold: 0.65
# Number of graphs created: 27
# ../Scripts/data/data_vigilia/0/1_vigilia sin 5.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 5.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 7.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4095.0)]
#
# Threshold: 0.65
# Number of graphs created: 24
# ../Scripts/data/data_vigilia/0/1_vigilia sin 6.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 7.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4095.0)]
#
# Threshold: 0.65
# Number of graphs created: 24
# ../Scripts/data/data_vigilia/0/1_vigilia sin 7.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 7.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia sin 8.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 8.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 4.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2559.0)]
#
# Threshold: 0.65
# Number of graphs created: 15
# ../Scripts/data/data_vigilia/0/1_vigilia sin 9.edf 0
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\0\1_vigilia sin 9.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 7.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4095.0)]
#
# Threshold: 0.65
# Number of graphs created: 24
# ../Scripts/data/data_vigilia/1/1_presalva 1.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 10.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 10.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 11.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 11.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 12.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 12.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 13.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 13.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 2.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 2.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 3.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 3.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 4.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 4.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 5.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 5.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 6.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 6.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 7.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 7.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 8.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 8.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/1_presalva 9.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\1_presalva 9.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33
# ../Scripts/data/data_vigilia/1/3_presalva 1.edf 1
# Extracting EDF parameters from d:\CEIEC\EEG-Epilepsy\EEG-Epilepsy\GCNN\Scripts\data\data_vigilia\1\3_presalva 1.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
#
# EEG Information.
# Number of Channels: 25
# Sample rate: 512.0 Hz.
# Duration: 10.998 seconds.
# Channel Names: ['EEG Fp1', 'EEG Fp2', 'EEG F3', 'EEG F4', 'EEG C3', 'EEG C4', 'EEG P3', 'EEG P4', 'EEG O1', 'EEG O2', 'EEG F7', 'EEG F8', 'EEG T3', 'EEG T4', 'EEG T5', 'EEG T6', 'EEG Fz', 'EEG Cz', 'EEG Pz', 'EEG FT9', 'EEG FT10', 'EEG T9', 'EEG T10', 'EEG TP9', 'EEG TP10']
# Model Data.
# Squared_coherence_Estimator()
# Frequency Bands: ['delta', 'theta', 'alpha', 'beta', 'gamma'] [False, True, True, True, False]
# Intervals:  [(0, 512.0), (512.0, 1024.0), (1024.0, 1536.0), (1536.0, 2048.0), (2048.0, 2560.0), (2560.0, 3072.0), (3072.0, 3584.0), (3584.0, 4096.0), (4096.0, 4608.0), (4608.0, 5120.0), (5120.0, 5631.0)]
#
# Threshold: 0.65
# Number of graphs created: 33

# %%
df=MyDataset(graphs,labels, transforms=NormalizeAdj())

# %% [markdown]
# ## division del dataset en varios para la red

# %%
idxs = np.random.permutation(len(df))
split_va, split_te = int(0.8 * len(df)), int(0.9 * len(df))
idx_tr, idx_va, idx_te = np.split(idxs, [split_va, split_te])
data_tr = df[idx_tr]
data_va = df[idx_va]
data_te = df[idx_te]

# %% [markdown]
# ## Utilizacion de un batch size y un loader de la libreria spektral

# %%
loader_tr = DisjointLoader(data_tr, batch_size=batch_size, epochs=epochs)
loader_va = DisjointLoader(data_va, batch_size=batch_size)
loader_te = DisjointLoader(data_te, batch_size=batch_size)

# %% [markdown]
# # Creacion de la GNN

# %%
class MyFirstGNN(Model):
     def __init__(self, n_hidden, n_labels):
        super().__init__()
        self.graph_conv = GCNConv(n_hidden)
        self.pool = GlobalSumPool()
        self.dropout = Dropout(0.5)
        self.dense = Dense(n_labels, 'softmax')

     def call(self, inputs):
        out = self.graph_conv(inputs)
        out = self.dropout(out)
        out = self.pool(out)
        out = self.dense(out)

        return out

optimizer = Adam(lr=learning_rate)
loss_fn = CategoricalCrossentropy()
# Out:
# D:\Anaconda\envs\Ceiec\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %% [markdown]
# ## aplicamos filtros para normalizar segun el paper

# %%
model = MyFirstGNN(32, df.n_labels)
model.compile(optimizer, loss_fn)

# %% [markdown]
# ### Hasta este punto, el código es funcional, a partir de aquí el problema radica en la propia red. El código es una implementación de cómo lo hacen varios ejemplos de la web oficial, combianando tanto la importación de datos y la conversion de objetos spektral hasta la implementación de la GCN, la cual es el modelo base que propone Kipf en su paper

# %%
model.fit(loader_tr,steps_per_epoch=1000, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18540/3546263562.py in <module>
# ----> 1 model.fit(loader_tr,labels ,steps_per_epoch=1000, epochs=10)
#
# D:\Anaconda\envs\Ceiec\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1132          training_utils.RespectCompiledTrainableState(self):
#    1133       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1134       data_handler = data_adapter.get_data_handler(
#    1135           x=x,
#    1136           y=y,
#
# D:\Anaconda\envs\Ceiec\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1381   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1382     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1383   return DataHandler(*args, **kwargs)
#    1384
#    1385
#
# D:\Anaconda\envs\Ceiec\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1136
#    1137     adapter_cls = select_data_adapter(x, y)
# -> 1138     self._adapter = adapter_cls(
#    1139         x,
#    1140         y,
#
# D:\Anaconda\envs\Ceiec\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     782
#     783     if not is_none_or_empty(y):
# --> 784       raise ValueError("`y` argument is not supported when using "
#     785                        "python generator as input.")
#     786     if not is_none_or_empty(sample_weights):
#
# ValueError: `y` argument is not supported when using python generator as input.
